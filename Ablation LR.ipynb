# %%
import matplotlib.pyplot as plt

algos = ['exp3', 'exp3_ix', 'exp3_soft_clip', 'exp3_clip']

etas = [0.001, 0.005, 0.01, 0.015, 0.02]


# n = 10 
# -------------
exp3 =     [11328.5 , 4481.1 , 3366.7 , 1533.9 , 2747.9 ]
exp3_std = [  594.85, 1096.99, 1141.63,  256.04,  891.91]

exp3_ix = []
exp3_ix_std = []

exp3_sc = []
exp3_sc_std = []

exp3_c = []
exp3_c_std = []

plt.errorbar(etas, exp3, exp3_std)
# plt.scatter(etas, exp3)
plt.show()



# n = 25
# -------------
exp3 =     [11577.7 , 3358   , 4979.0 , 3273.5 , 4250.8 ]
exp3_std = [  554.18,  535.92, 1404.28,  495.52,  725.84]

exp3_ix = []
exp3_ix_std = []

exp3_sc = []
exp3_sc_std = []

exp3_c = []
exp3_c_std = []

plt.errorbar(etas, exp3, exp3_std)
plt.show()


# n = 50
# -------------
exp3 =     [11911.7 , 5435.1 , 4830.7 , ]
exp3_std = [  329.58,  801.85,  661.42, ]

exp3_ix = []
exp3_ix_std = []

exp3_sc = []
exp3_sc_std = []

exp3_c = []
exp3_c_std = []

plt.errorbar(etas, exp3, exp3_std)
plt.show()
