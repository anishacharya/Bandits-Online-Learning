# %%
import matplotlib.pyplot as plt

algos = ['exp3', 'exp3_ix', 'exp3_soft_clip', 'exp3_clip']
etas = [0.001, 0.005, 0.01, 0.02]



########## Binomial Reward ####### 
# n = 10 
# -------------
exp3 =     [11328.5 , 4481.1 , 3366.7 , 2747.9 ]
exp3_std = [  594.85, 1096.99, 1141.63, 891.91]

exp3_ix     = [9085.6 , 2536.5, 2518.6, 3585.5]
exp3_ix_std = [ 284.41, 128.38,  99.72, 119.75]

exp3_c     = [9765.1 , 2204.1, 1769.4, 2181.5]
exp3_c_std = [ 395.61, 129.83, 120.43, 115.61]

exp3_sc     = [9179.3 , 2293.5, 1984.6, 2629.0]
exp3_sc_std = [ 248.15, 142.59, 143.81, 123.06]

plt.errorbar(etas, exp3, exp3_std, color='b', label='EXP3')
plt.errorbar(etas, exp3_ix, exp3_ix_std, color='r', label='EXP3-IX')
plt.errorbar(etas, exp3_c, exp3_c_std, color='g', label='EXP3-Clip')
plt.errorbar(etas, exp3_sc, exp3_sc_std, color='k', label='EXP3-softClip')

plt.xlabel('Varying Learning Rate')
plt.ylabel('Cummulative Regret')
plt.xticks(etas)
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()



# n = 25
# -------------
exp3 =     [11577.7 , 3358   , 4979.0 , 4250.8 ]
exp3_std = [  554.18,  535.92, 1404.28,  725.84]

exp3_ix     = [9805.6, 3920.0, 5009.8, 6304.2]
exp3_ix_std = [312.92, 142.43, 163.32, 117.93]

exp3_c     = [10227.1, 3237.2, 3281.3, 4888.2]
exp3_c_std = [  402.2, 245.90, 173.71, 150.02]

exp3_sc     = [9827.0, 3542.2, 3886.6, 5053.5]
exp3_sc_std = [289.86, 330.20, 263.08, 145.65]

plt.errorbar(etas, exp3, exp3_std, color='b', label='EXP3')
plt.errorbar(etas, exp3_ix, exp3_ix_std, color='r', label='EXP3-IX')
plt.errorbar(etas, exp3_c, exp3_c_std, color='g', label='EXP3-Clip')
plt.errorbar(etas, exp3_sc, exp3_sc_std, color='k', label='EXP3-softClip')

plt.xlabel('Varying Learning Rate')
plt.ylabel('Cummulative Regret')
plt.xticks(etas)
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()


# n = 50
# -------------
exp3     = [11911.7, 5435.1, 4830.7, 6231.2]
exp3_std = [  329.5,  801.8,  661.4, 1088.6]

exp3_ix     = [10707.3, 6269.0, 6931.8, 8252.9]
exp3_ix_std = [ 206.72, 179.86,  142.9, 149.70]

exp3_c     = [11725.8, 4738.5, 5732.5, 7093.4]
exp3_c_std = [ 438.94, 250.64, 264.89, 156.94]

exp3_sc     = [12640.2, 5485.2, 6218.9, 6579.3]
exp3_sc_std = [ 523.01, 255.65, 244.03, 162.04]

plt.errorbar(etas, exp3, exp3_std, color='b', label='EXP3')
plt.errorbar(etas, exp3_ix, exp3_ix_std, color='r', label='EXP3-IX')
plt.errorbar(etas, exp3_c, exp3_c_std, color='g', label='EXP3-Clip')
plt.errorbar(etas, exp3_sc, exp3_sc_std, color='k', label='EXP3-softClip')

plt.xlabel('Varying Learning Rate')
plt.ylabel('Cummulative Regret')
plt.xticks(etas)
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()

# %%
########## Truncated Normal Reward ####### 

etas = [0.001, 0.005, 0.01, 0.015, 0.02]

# n = 10 
# -------------
exp3     = [10045.11, 3606.49, 1434.65, 1395.28,  1555.70]
exp3_std = [  379.99, 952.06, 208.75, 221.19, 491.34]

exp3_ix     = [8661.38, 2271.37, 2217.81, 2623.66, 3129.65]
exp3_ix_std = [ 135.64, 72.35, 48.34, 45.60, 49.74]

exp3_c     = [9385.85, 2063.15, 1435.99, 1449.39, 1631.01]
exp3_c_std = [ 187.61, 90.55, 66.81, 46.58, 43.22]

exp3_sc     = [9212.43, 2087.43, 1641.28, 1802.64, 2051.89]
exp3_sc_std = [ 205.64, 87.73, 58.21, 53.76, 61.66]


plt.errorbar(etas, exp3, exp3_std, color='b', label='EXP3')
plt.errorbar(etas, exp3_ix, exp3_ix_std, color='r', label='EXP3-IX')
plt.errorbar(etas, exp3_c, exp3_c_std, color='g', label='EXP3-Clip')
plt.errorbar(etas, exp3_sc, exp3_sc_std, color='k', label='EXP3-softClip')

plt.xlabel('Varying Learning Rate')
plt.ylabel('Cummulative Regret')
plt.xticks(etas)
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()



# n = 25
# -------------
exp3 =     [11699.72, 4331.3, 2065.4, 2556.72, 2266.02]
exp3_std = [466.3, 996.3, 440.4, 489.1, 306.9]

exp3_ix = [9919.8, 3651.2, 4488.62, 5470.32, 6046.30]
exp3_ix_std = [310.0, 159.2, 149.9, 83.81, 58.40]

exp3_c = [10672.3, 2695.18, 2578.41, 3002.9, 3666.64]
exp3_c_std = [276.1, 123.4, 87.56, 64.15, 72.10]

exp3_sc = [10242.65, 2993.9, 3183.1, 3855.44, 4485.54]
exp3_sc_std = [320.01, 112.3, 112.8, 97.40, 131.20]

plt.errorbar(etas, exp3, exp3_std, color='b', label='EXP3')
plt.errorbar(etas, exp3_ix, exp3_ix_std, color='r', label='EXP3-IX')
plt.errorbar(etas, exp3_c, exp3_c_std, color='g', label='EXP3-Clip')
plt.errorbar(etas, exp3_sc, exp3_sc_std, color='k', label='EXP3-softClip')

plt.xlabel('Varying Learning Rate')
plt.ylabel('Cummulative Regret')
plt.xticks(etas)
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()


etas = [0.001, 0.005, 0.01, 0.015]
# n = 50
# -------------
exp3 =     [13625.03, 3708.92, 3589.77, 5130.23]
exp3_std = [459.57, 534.71, 678.20, 1296.63]

exp3_ix = [10874.90, 5766.53, 6731.5, 7363.78]
exp3_ix_std = [209.7, 175.55, 74.04, 43.73]

exp3_c = [11462.087,  3844.19, 4300.69, 5547.19]
exp3_c_std = [268.08, 178.08, 142.95, 127.27]

exp3_sc = [11140.08, 4433.37, 5251.03, 5935.08]
exp3_sc_std = [327.12, 207.33, 154, 122.08]

plt.errorbar(etas, exp3, exp3_std, color='b', label='EXP3')
plt.errorbar(etas, exp3_ix, exp3_ix_std, color='r', label='EXP3-IX')
plt.errorbar(etas, exp3_c, exp3_c_std, color='g', label='EXP3-Clip')
plt.errorbar(etas, exp3_sc, exp3_sc_std, color='k', label='EXP3-softClip')

plt.xlabel('Varying Learning Rate')
plt.ylabel('Cummulative Regret')
plt.xticks(etas)
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()
