# %%
import matplotlib.pyplot as plt

algos = ['exp3', 'exp3_ix', 'exp3_soft_clip', 'exp3_clip']
etas = [0.001, 0.005, 0.01, 0.015, 0.02]



########## Binomial Reward ####### 
# n = 10 
# -------------
exp3 =     [11328.5 , 4481.1 , 3366.7 , 1533.9 , 2747.9 ]
exp3_std = [  594.85, 1096.99, 1141.63,  256.04,  891.91]

exp3_ix     = [9085.6 , 2536.5, 2518.6, 3035.0, 3585.5]
exp3_ix_std = [ 284.41, 128.38,  99.72, 104.24, 119.75]

exp3_c     = [9765.1 , 2204.1, 1769.4, 1898.4, 2181.5]
exp3_c_std = [ 395.61, 129.83, 120.43, 136.78, 115.61]

exp3_sc     = [9179.3 , 2293.5, 1984.6, 2237.9, 2629.0]
exp3_sc_std = [ 248.15, 142.59, 143.81, 122.84, 123.06]

plt.errorbar(etas, exp3, exp3_std, color='b', label='EXP3')
plt.errorbar(etas, exp3_ix, exp3_ix_std, color='r', label='EXP3-IX')
plt.errorbar(etas, exp3_c, exp3_c_std, color='g', label='EXP3-Clip')
plt.errorbar(etas, exp3_sc, exp3_sc_std, color='k', label='EXP3-softClip')

plt.xlabel('Varying Learning Rate')
plt.ylabel('Cummulative Regret')
plt.xticks(etas)
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()



# n = 25
# -------------
exp3 =     [11577.7 , 3358   , 4979.0 , 3273.5 ,  4250.8 ]
exp3_std = [  554.18,  535.92, 1404.28,  495.52,  725.84]

exp3_ix     = [9805.6, 3920.0, 5009.8, 5769.3, 6304.2]
exp3_ix_std = [312.92, 142.43, 163.32, 166.55, 117.93]

exp3_c     = [10227.1, 3237.2, 3281.3, 4070.7, 4888.2]
exp3_c_std = [  402.2, 245.90, 173.71, 187.61, 150.02]

exp3_sc     = [9827.0, 3542.2, 3886.6, 4617.1, 5053.5]
exp3_sc_std = [289.86, 330.20, 263.08, 147.44, 145.65]

plt.errorbar(etas, exp3, exp3_std, color='b', label='EXP3')
plt.errorbar(etas, exp3_ix, exp3_ix_std, color='r', label='EXP3-IX')
plt.errorbar(etas, exp3_c, exp3_c_std, color='g', label='EXP3-Clip')
plt.errorbar(etas, exp3_sc, exp3_sc_std, color='k', label='EXP3-softClip')

plt.xlabel('Varying Learning Rate')
plt.ylabel('Cummulative Regret')
plt.xticks(etas)
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()


# n = 50
# -------------
exp3     = [11911.7, 5435.1, 4830.7, 7058.1, 6231.2]
exp3_std = [  329.5,  801.8,  661.4, 1431.5, 1088.6]

exp3_ix     = [10707.3, 6269.0, 6931.8, 7629.2, 8252.9]
exp3_ix_std = [ 206.72, 179.86,  142.9, 138.45, 149.70]

exp3_c     = [11725.8, 4738.5, 5732.5, 6577.6, 7093.4]
exp3_c_std = [ 438.94, 250.64, 264.89, 176.75, 156.94]

exp3_sc     = [12640.2, 5485.2, 6218.9, 6369.0, 6579.3]
exp3_sc_std = [ 523.01, 255.65, 244.03, 176.35, 162.04]

plt.errorbar(etas, exp3, exp3_std, color='b')
plt.xticks(etas)
plt.show()

# %%
########## Truncated Normal Reward ####### 

# n = 10 
# -------------
exp3     = [10045.11, ]
exp3_std = [  379.99, ]

exp3_ix     = [8661.38, ]
exp3_ix_std = [ 135.64, ]

exp3_c     = [9385.85, ]
exp3_c_std = [ 187.61, ]

exp3_sc     = [9212.43, ]
exp3_sc_std = [ 205.64, ]


plt.errorbar(etas, exp3, exp3_std, color='b')
plt.xticks(etas)
# plt.scatter(etas, exp3)
plt.show()



# n = 25
# -------------
exp3 =     []
exp3_std = []

exp3_ix = []
exp3_ix_std = []

exp3_sc = []
exp3_sc_std = []

exp3_c = []
exp3_c_std = []

plt.errorbar(etas, exp3, exp3_std, color='b')
plt.xticks(etas)
plt.show()


# n = 50
# -------------
exp3 =     []
exp3_std = []

exp3_ix = []
exp3_ix_std = []

exp3_sc = []
exp3_sc_std = []

exp3_c = []
exp3_c_std = []

plt.errorbar(etas, exp3, exp3_std, color='b')
plt.xticks(etas)
plt.show()
